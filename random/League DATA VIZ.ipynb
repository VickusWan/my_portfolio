# %%
import seaborn as sns
import pandas as pd
from sklearn import preprocessing
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("_levels.csv")

# %%
df.drop(['Unnamed: 0'], axis = 1, inplace = True)
df
# Out:
#              matchID  total kills  total deaths  total assists  Damage Dealt  \
# 0     NA1_4170259244           67            62            120        159705
# 1     NA1_4170259244           62            67            139        134072
# 2     NA1_4170247360           24            12             70         38741
# 3     NA1_4170247360           12            24             28         28424
# 4     NA1_4170186384           72            66            203        218941
# ...              ...          ...           ...            ...           ...
# 6063     3633817223L           55            46            140        463448
# 6064     3633817223W           69            72            135        552494
# 6065     3633817223L           72            69            138        566353
# 6066     3633817223W           63            62            139        482339
# 6067     3633817223L           62            63            146        469383
#
#       Damage Taken  Summoner Avg Level  average levels  Total Gold Earned  \
# 0           154051                1141           228.2              74952
# 1           165349                1130           226.0              71605
# 2            34321                1128           225.6              38547
# 3            40546                1182           236.4              31392
# 4           215416                 811           162.2              95289
# ...            ...                 ...             ...                ...
# 6063        138660                 701           140.2              71890
# 6064        171331                1050           210.0              89368
# 6065        244314                 996           199.2              90331
# 6066        178200                 992           198.4              79914
# 6067        195911                 625           125.0              78632
#
#       #Assassins  #Fighters  #Mages  #Marksman  #Supports  #Tanks  WIN/LOSS?  \
# 0              3          3       2          0          1       0          1
# 1              1          1       2          1          1       2          0
# 2              1          0       2          2          2       0          1
# 3              1          3       2          1          0       1          0
# 4              2          1       3          1          0       1          1
# ...          ...        ...     ...        ...        ...     ...        ...
# 6063           1          1       2          2          2       0          0
# 6064           1          0       2          4          1       0          1
# 6065           0          3       2          2          1       2          0
# 6066           1          1       2          2          0       1          1
# 6067           0          2       1          2          2       1          0
#
#      win/loss cat
# 0             WIN
# 1            LOSS
# 2             WIN
# 3            LOSS
# 4             WIN
# ...           ...
# 6063         LOSS
# 6064          WIN
# 6065         LOSS
# 6066          WIN
# 6067         LOSS
#
# [6068 rows x 17 columns]

# %%
df = pd.read_csv("_levels.csv")
df_copy = df

#le = preprocessing.LabelEncoder()
#df_copy['WIN/LOSS?']=le.fit_transform(df_copy['WIN/LOSS?'])

# WIN = 0
# LOSS = 0


win = df_copy[df['WIN/LOSS?'] == 'WIN']
loss = df_copy[df['WIN/LOSS?'] == 'LOSS']
df
# Out:
#       Unnamed: 0      matchID  total kills  total deaths  total assists  \
# 0              0  3633340047W           43            60             97
# 1              1  3633340047L           58            43            170
# 2              2  3633340047W           39            42             93
# 3              3  3633340047L           42            39             98
# 4              4  3633340047W           43            33             92
# ...          ...          ...          ...           ...            ...
# 2063         185  3633817223L           55            46            140
# 2064         186  3633817223W           69            72            135
# 2065         187  3633817223L           72            69            138
# 2066         188  3633817223W           63            62            139
# 2067         189  3633817223L           62            63            146
#
#       Damage Dealt  Damage Taken  Time CC'ed  Total Gold Earned  \
# 0           388195        187097         234              70087
# 1           424275        146323         179              71260
# 2           327363        149827         156              65735
# 3           338459        133510         192              62729
# 4           273766         91827          97              57130
# ...            ...           ...         ...                ...
# 2063        463448        138660         139              71890
# 2064        552494        171331         145              89368
# 2065        566353        244314         156              90331
# 2066        482339        178200         150              79914
# 2067        469383        195911         135              78632
#
#       First Blood Turret  #Assassins  #Fighters  #Mages  #Marksman  #Supports  \
# 0                      0           2          0       3          1          0
# 1                      1           0          2       4          1          3
# 2                      1           1          2       2          1          2
# 3                      0           2          1       4          0          2
# 4                      1           0          2       3          1          0
# ...                  ...         ...        ...     ...        ...        ...
# 2063                   0           1          1       2          2          2
# 2064                   0           1          0       2          4          1
# 2065                   1           0          3       2          2          1
# 2066                   0           1          1       2          2          0
# 2067                   0           0          2       1          2          2
#
#       #Tanks WIN/LOSS?
# 0          3       WIN
# 1          0      LOSS
# 2          2       WIN
# 3          0      LOSS
# 4          1       WIN
# ...      ...       ...
# 2063       0      LOSS
# 2064       0       WIN
# 2065       2      LOSS
# 2066       1       WIN
# 2067       1      LOSS
#
# [2068 rows x 17 columns]

# %%
a = df.groupby(['WIN/LOSS?']).sum()
tags = a[['#Assassins', '#Fighters', '#Mages', '#Marksman', '#Supports', '#Tanks']].copy()
tags
loss = tags.iloc[[0]]
win = tags.iloc[[1]]
tags
# Out:
#            #Assassins  #Fighters  #Mages  #Marksman  #Supports  #Tanks
# WIN/LOSS?
# LOSS             1305       1760    2200       1333       1169    1092
# WIN              1165       1710    2263       1330       1179    1196

# %%
sns.color_palette("pastel")
fig, axes = plt.subplots(1, 2, figsize=(15, 5))
sns.barplot(ax=axes[0], data=win, color="lightgreen")
axes[0].set_title('Distribution Winning Champion Classes')
sns.barplot(ax=axes[1], data=loss, color='tomato')
axes[1].set_title('Distribution Losing Champion Classes')
# Out:
# Text(0.5, 1.0, 'Distribution Losing Champion Classes')

# %%
df_copy = df.copy()
df_copy = df_copy.drop(df_copy.columns[0:10], axis=1)
df_melt = pd.melt(df_copy, id_vars=["WIN/LOSS?"], value_vars=["#Assassins", "#Fighters", "#Mages", "#Marksman", "#Supports", "#Tanks"], var_name="Attribute", value_name="Frequency")
sns.catplot(x='Attribute', y='Frequency', hue='WIN/LOSS?',  palette="muted" , data=df_melt, kind='bar', height=7, aspect=2)
plt.title("Distribution of Champion Classes")
# Out:
# Text(0.5, 1.0, 'Distribution of Champion Classes')

# %%
win_col = df_copy[df['WIN/LOSS?'] == 'WIN']
loss_col = df_copy[df['WIN/LOSS?'] == 'LOSS']
win_col
# Out:
#       Unnamed: 0      matchID  total kills  total deaths  total assists  \
# 0              0  3633340047W           43            60             97
# 2              2  3633340047W           39            42             93
# 4              4  3633340047W           43            33             92
# 6              6  3633340047W           41            42             91
# 8              8  3633340047W           41            25            111
# ...          ...          ...          ...           ...            ...
# 2058         180  3633817223W           37            27            103
# 2060         182  3633817223W           56            33             94
# 2062         184  3633817223W           46            55            109
# 2064         186  3633817223W           69            72            135
# 2066         188  3633817223W           63            62            139
#
#       Damage Dealt  Damage Taken  Time CC'ed  Total Gold Earned  \
# 0           388195        187097         234              70087
# 2           327363        149827         156              65735
# 4           273766         91827          97              57130
# 6           226358        102199          51              55065
# 8           182584         68565          74              46395
# ...            ...           ...         ...                ...
# 2058        230384         87505          84              54263
# 2060        285452         85024         116              61626
# 2062        392247        184677         183              72601
# 2064        552494        171331         145              89368
# 2066        482339        178200         150              79914
#
#       First Blood Turret  #Assassins  #Fighters  #Mages  #Marksman  #Supports  \
# 0                      0           2          0       3          1          0
# 2                      1           1          2       2          1          2
# 4                      1           0          2       3          1          0
# 6                      0           2          3       2          1          0
# 8                      1           1          3       0          1          0
# ...                  ...         ...        ...     ...        ...        ...
# 2058                   0           0          0       2          3          2
# 2060                   0           2          1       4          1          0
# 2062                   1           2          1       2          1          2
# 2064                   0           1          0       2          4          1
# 2066                   0           1          1       2          2          0
#
#       #Tanks WIN/LOSS?
# 0          3       WIN
# 2          2       WIN
# 4          1       WIN
# 6          0       WIN
# 8          2       WIN
# ...      ...       ...
# 2058       1       WIN
# 2060       1       WIN
# 2062       1       WIN
# 2064       0       WIN
# 2066       1       WIN
#
# [1034 rows x 17 columns]

# %%
dd_w = win_col['Damage Dealt']
dd_L = loss_col['Damage Dealt']
dT_w = win_col['Damage Taken']
dT_L = loss_col['Damage Taken']
gold_w = win_col['Total Gold Earned']
gold_L = loss_col['Total Gold Earned']
f, axes = plt.subplots(1, 3, figsize=(20, 5), sharex=False)
sns.distplot(dd_w, kde = False, bins = 75, ax=axes[0])
sns.distplot(dd_L, kde = False, bins = 75, ax=axes[0])
sns.distplot(dT_w, kde = False, bins = 75, ax=axes[1])
sns.distplot(dT_L, kde = False, bins = 75, ax=axes[1])
sns.distplot(gold_w, kde = False, bins = 75, ax=axes[2])
sns.distplot(gold_L, kde = False, bins = 75, ax=axes[2])
axes[0].legend(labels=['win', 'loss'])
axes[0].title.set_text('Total Damage Dealt per Team')
axes[1].legend(labels=['win', 'loss'])
axes[1].title.set_text('Total Damage Taken per Team')
axes[2].legend(labels=['win', 'loss'])
axes[2].title.set_text('Total Gold Earned per Team')

# %%
sns.scatterplot(data=win_col, x='total assists', y='total deaths', color='skyblue', legend = 'full')
sns.scatterplot(data=loss_col, x='total assists', y='total deaths', color='sandybrown', legend = 'full')
plt.legend(labels=['win', 'loss'])
plt.title('KDA dispersion')
# Out:
# Text(0.5, 1.0, 'KDA dispersion')
